# %% [markdown]
# # NEWRVC: High-Performance Engine + Ultimate Workflows 🚀
# Welcome to the NewRVC Google Colab! This environment is built for Python 3.11.
#
# It merges the core engine of `codename-rvc-fork-4` (RingFormer, PCPH-GAN, Spin) with the intuitive workflows of `Ultimate RVC` (Auto YouTube Download, Python-Audio-Separator for MDX Kim Vocals 2 / Demucs).
#
# ## 1. Install Dependencies

# %%
# Set up Python 3.11 environment for strict compatibility
# !apt-get update -y
# !apt-get install python3.11 python3.11-venv python3.11-dev -y
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.11

# Clone the repository from GitHub
# !git clone https://github.com/DDME36/NEWRVC.git

import os
os.chdir('/content/NEWRVC')

# !python3.11 -m pip install -r requirements.txt

# %% [markdown]
# ## 2. Start the Gradio UI
# This will automatically download any missing core models on first run and expose a public Gradio link.

# %%
# !python3.11 app.py --share
